# %% [markdown]
# ## 1. Get the list of datasets available in pycaret (Total Datasets = 56)

# %%
from pycaret.datasets import get_data
dataset = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %% [markdown]
# ## 2. Get the "Insurance" dataset

# %%
dataset = get_data('insurance')
dataset
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# ...

# %% [markdown]
# ## 3. "Parameter setting" for all regression models

# %%
from pycaret.regression import *
s = setup(data=dataset, target='charges',train_size=0.7)

# in setup to start machine learning and the function automatically 
# missing value imputation and categorical encoding
# Out:
# <style type="text/css">
# #T_b9875_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b9875">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9875_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b9875_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9875_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9875_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b9875_row0_col1" class="data row0 col1" >300</td>
#     </tr>
#     <tr>
#       <th id="T_b9875_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9875_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b9875_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_b9875_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# ## 4. "Run and Compare" the Models Performance

# %%
cm = compare_models()
#compare models using a all models in the models libary using crossing validation
# Out:
# <style type="text/css">
# #T_7f706 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## 5. "Three lines of code" for model comparasion for "Insurance" dataset

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

dataset = get_data('insurance')
s = setup(data=dataset, target='charges')
cm = compare_models()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_dbc63_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dbc63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbc63_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dbc63_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbc63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbc63_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# ## 6. Build a single model - "Gradient Boosting Regressor"

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

data = get_data('insurance')
s = setup(data=data, target='charges', train_size=0.7)
model = create_model('gbr')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <style type="text/css">
# #T_b9648_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b9648">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9648_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b9648_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9648_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9648_row0_col0" class="data row0 col0" >Session id</td>
# ...

# %% [markdown]
# ## 7. "Save" the trained model

# %%
sm = save_model(model, 'model_save_grb')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ## 8. "Load the model" -> "Make Prediction" on  "New unseen data"

# %% [markdown]
# ## 8.1 load the "Model"

# %%
model = load_model('model_save_grb')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ## 8.2 Make model prediction on "New unseen dataset"

# %%
import pandas as pd
data = {'age':40,
        'sex':1,
        'bmi':40.35,
        'children':4,
        'smoker':1,
        'region':2}
#index = [1]
df=pd.DataFrame(data,index=[0])
df
# Out:
#    age  sex    bmi  children  smoker  region
# 0   40    1  40.35         4       1       2

# %%
pred = predict_model(model,df)

# %%
pred
